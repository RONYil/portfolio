# %%
from pipetorch.train import *
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from sklearn.metrics import f1_score
import torchvision.transforms as transforms
import torchvision.utils as vutils

# %%
image_size = 64
batch_size = 64

# %%
transform=transforms.Compose([

  transforms.Resize((image_size, image_size)),  

  transforms.ToTensor(),

  transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

])

# %%
# 设置训练数据集路径
train_ds_path = r'C:\Users\yil\Desktop\ipy project\bot-project\Car-deployment_3\train_ds'

# 加载训练数据集
train_ds = torchvision.datasets.ImageFolder(
    train_ds_path,  # 训练集的路径
    transform=transform
)

# 设置验证数据集路径
valid_ds_path = r'C:\Users\yil\Desktop\ipy project\bot-project\Car-deployment_3\valid_ds'

# 加载验证数据集
valid_ds = torchvision.datasets.ImageFolder(
    valid_ds_path,  # 验证集的路径
    transform=transform
)

# %%
train_dl = DataLoader(train_ds, batch_size=batch_size,shuffle=True, num_workers=2)
valid_dl = DataLoader(valid_ds, batch_size=batch_size,shuffle=True, num_workers=2)

# %%
def demo_batch():
    real_batch = next(iter(train_dl))
    plt.figure(figsize=(8,8))
    plt.axis("off")
    plt.title("Training Images")
    showx(vutils.make_grid(real_batch[0][:64], padding=2, normalize=True))

# %%
ds = train_dl.dataset

# %%
X, y = next(iter(train_dl))
X.shape
# Out:
# torch.Size([64, 3, 64, 64])

# %%
def showx(x):
    plt.imshow(np.transpose(x,(1,2,0)))

# %%
y.shape
# Out:
# torch.Size([64])

# %%
demo_batch()

# %%
def convnet1(image_size=64):
    return nn.Sequential(
        # 第一层卷积层，减少通道数
        nn.Conv2d(3, 4, kernel_size=3, stride=1, padding=1),  # 输出：64x64x4
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2, stride=2),  # 输出：32x32x4

        # 第二层卷积层
        nn.Conv2d(4, 8, kernel_size=3, stride=1, padding=1),  # 输出：32x32x8
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2, stride=2),  # 输出：16x16x8

        # 第三层卷积层
        nn.Conv2d(8, 16, kernel_size=3, stride=1, padding=1),  # 输出：16x16x16
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2, stride=2),  # 输出：8x8x16
        
        nn.Flatten(),  # Flatten the output

        # 全连接层
        nn.Linear(16 * 8 * 8, 128),  # 修改全连接层输入大小：16 * 8 * 8 = 1024
        nn.ReLU(),

        # Dropout 层，减少过拟合
        nn.Dropout(0.3),

        # 输出层
        nn.Linear(128, 3)  # 输出 3 个类别
    )

# %%
model = convnet1()

# %%
# 定义损失函数，适合二分类任务的交叉熵损失
loss_fn = nn.CrossEntropyLoss()

# 假设 train_dl 和 valid_dl 是已经创建好的数据加载器
# 创建 Trainer 对象
t = Trainer(model=model, 
            loss=loss_fn, 
            train_dl=train_dl, 
            valid_dl=valid_dl, 
            metrics=accuracy_score,  # 评价标准为准确率
            halt_notebook=False)  # 是否在 notebook 中停止训练

# %%
t.train(100, (1e-3, 1e-2), cycle=1)
# Out:
# Total:   0%|          | 0/19200 [00:00<?, ?it/s]
#   1 9.45s trainloss=1.08647 validloss=1.04837 accuracy_score=0.46667
#   2 10.19s trainloss=1.12159 validloss=1.04021 accuracy_score=0.43333
#   3 10.31s trainloss=1.07568 validloss=1.01928 accuracy_score=0.43333
#   4 10.03s trainloss=1.01196 validloss=0.98540 accuracy_score=0.45000
#   5 10.08s trainloss=0.94051 validloss=0.99975 accuracy_score=0.45333
#   6 10.72s trainloss=0.89913 validloss=0.97421 accuracy_score=0.48333
#   7 10.90s trainloss=0.87234 validloss=0.94622 accuracy_score=0.51429
#   8 11.40s trainloss=0.83396 validloss=0.92304 accuracy_score=0.54583
#   9 12.19s trainloss=0.80328 validloss=0.89960 accuracy_score=0.57407
#  10 10.85s trainloss=0.78467 validloss=0.87828 accuracy_score=0.59667
#  11 10.97s trainloss=0.76269 validloss=0.86065 accuracy_score=0.61515
#  12 10.96s trainloss=0.74334 validloss=0.84232 accuracy_score=0.62778
#  13 10.27s trainloss=0.72158 validloss=0.85759 accuracy_score=0.63333
#  14 10.11s trainloss=0.70930 validloss=0.86241 accuracy_score=0.62619
#  15 10.44s trainloss=0.70986 validloss=0.85817 accuracy_score=0.62444
#  16 10.00s trainloss=0.70081 validloss=0.84484 accuracy_score=0.62917
#  17 10.46s trainloss=0.68628 validloss=0.83143 accuracy_score=0.63922
#  18 12.42s trainloss=0.67234 validloss=0.81935 accuracy_score=0.65000
#  19 9.96s trainloss=0.66027 validloss=0.80700 accuracy_score=0.65789
#  20 10.40s trainloss=0.64725 validloss=0.79550 accuracy_score=0.66500
#  21 10.62s trainloss=0.63443 validloss=0.78264 accuracy_score=0.67302
#  22 10.48s trainloss=0.62316 validloss=0.77179 accuracy_score=0.67879
#  23 10.76s trainloss=0.61070 validloss=0.76352 accuracy_score=0.68551
#  24 10.79s trainloss=0.60153 validloss=0.75245 accuracy_score=0.69167
#  25 10.17s trainloss=0.59048 validloss=0.74099 accuracy_score=0.69733
#  26 10.38s trainloss=0.58060 validloss=0.73020 accuracy_score=0.70256
#  27 10.20s trainloss=0.56990 validloss=0.72354 accuracy_score=0.70741
#  28 9.93s trainloss=0.55978 validloss=0.71652 accuracy_score=0.71190
#  29 10.21s trainloss=0.55185 validloss=0.70711 accuracy_score=0.71724
#  30 10.21s trainloss=0.54394 validloss=0.69863 accuracy_score=0.72111
#  31 10.23s trainloss=0.53470 validloss=0.69152 accuracy_score=0.72366
#  32 10.67s trainloss=0.52560 validloss=0.68652 accuracy_score=0.72604
#  33 10.86s trainloss=0.51771 validloss=0.68153 accuracy_score=0.73030
#  34 10.52s trainloss=0.50895 validloss=0.67591 accuracy_score=0.73431
#  35 10.48s trainloss=0.50215 validloss=0.66972 accuracy_score=0.73714
#  36 10.22s trainloss=0.49603 validloss=0.66348 accuracy_score=0.74074
#  37 10.62s trainloss=0.48902 validloss=0.65828 accuracy_score=0.74324
#  38 10.21s trainloss=0.48172 validloss=0.65322 accuracy_score=0.74649
#  39 10.02s trainloss=0.47604 validloss=0.64804 accuracy_score=0.74957
#  40 10.33s trainloss=0.46911 validloss=0.64347 accuracy_score=0.75250
#  41 10.34s trainloss=0.46321 validloss=0.63867 accuracy_score=0.75528
#  42 11.05s trainloss=0.45769 validloss=0.63409 accuracy_score=0.75714
#  43 10.41s trainloss=0.45205 validloss=0.62810 accuracy_score=0.75969
#  44 10.62s trainloss=0.44613 validloss=0.62302 accuracy_score=0.76212
#  45 10.18s trainloss=0.44018 validloss=0.61873 accuracy_score=0.76370
#  46 10.64s trainloss=0.43505 validloss=0.61438 accuracy_score=0.76594
#  47 10.69s trainloss=0.42898 validloss=0.61005 accuracy_score=0.76809
#  48 10.67s trainloss=0.42406 validloss=0.60544 accuracy_score=0.77014
#  49 10.49s trainloss=0.41868 validloss=0.60090 accuracy_score=0.77347
#  50 10.54s trainloss=0.41265 validloss=0.59742 accuracy_score=0.77533
#  51 10.09s trainloss=0.40749 validloss=0.59317 accuracy_score=0.77843
#  52 10.15s trainloss=0.40229 validloss=0.58966 accuracy_score=0.78013
#  53 9.88s trainloss=0.39733 validloss=0.58665 accuracy_score=0.78239
#  54 9.97s trainloss=0.39274 validloss=0.58268 accuracy_score=0.78519
#  55 10.54s trainloss=0.38751 validloss=0.57944 accuracy_score=0.78727
#  56 9.94s trainloss=0.38285 validloss=0.57608 accuracy_score=0.78988
#  57 10.67s trainloss=0.37792 validloss=0.57424 accuracy_score=0.79181
#  58 10.66s trainloss=0.37284 validloss=0.57067 accuracy_score=0.79425
#  59 10.36s trainloss=0.36779 validloss=0.56665 accuracy_score=0.79661
#  60 10.29s trainloss=0.36282 validloss=0.56270 accuracy_score=0.79833
#  61 7.62s trainloss=0.35810 validloss=0.55891 accuracy_score=0.80055
#  62 7.50s trainloss=0.35334 validloss=0.55566 accuracy_score=0.80269
#  63 7.38s trainloss=0.34836 validloss=0.55347 accuracy_score=0.80476
#  64 7.40s trainloss=0.34369 validloss=0.55118 accuracy_score=0.80677
#  65 7.36s trainloss=0.33884 validloss=0.54821 accuracy_score=0.80872
#  66 9.60s trainloss=0.33415 validloss=0.54536 accuracy_score=0.81111
#  67 10.17s trainloss=0.32975 validloss=0.54248 accuracy_score=0.81343
#  68 9.75s trainloss=0.32525 validloss=0.53968 accuracy_score=0.81569
#  69 10.07s trainloss=0.32076 validloss=0.53727 accuracy_score=0.81739
#  70 9.88s trainloss=0.31678 validloss=0.53517 accuracy_score=0.81905
#  71 10.25s trainloss=0.31273 validloss=0.53435 accuracy_score=0.82019
#  72 10.55s trainloss=0.30876 validloss=0.53223 accuracy_score=0.82222
#  73 10.93s trainloss=0.30475 validloss=0.52966 accuracy_score=0.82374
#  74 10.80s trainloss=0.30092 validloss=0.52750 accuracy_score=0.82523
#  75 10.09s trainloss=0.29703 validloss=0.52624 accuracy_score=0.82667
#  76 9.80s trainloss=0.29318 validloss=0.52639 accuracy_score=0.82807
#  77 10.21s trainloss=0.28978 validloss=0.52554 accuracy_score=0.82944
#  78 10.22s trainloss=0.28629 validloss=0.52383 accuracy_score=0.83077
#  79 9.86s trainloss=0.28272 validloss=0.52265 accuracy_score=0.83165
#  80 10.45s trainloss=0.28001 validloss=0.52063 accuracy_score=0.83333
#  81 9.71s trainloss=0.27701 validloss=0.52116 accuracy_score=0.83416
#  82 10.05s trainloss=0.27408 validloss=0.52170 accuracy_score=0.83537
#  83 10.20s trainloss=0.27162 validloss=0.51982 accuracy_score=0.83655
#  84 10.27s trainloss=0.26889 validloss=0.51766 accuracy_score=0.83810
#  85 10.41s trainloss=0.26610 validloss=0.51698 accuracy_score=0.83843
#  86 10.18s trainloss=0.26375 validloss=0.51621 accuracy_score=0.83953
#  87 10.12s trainloss=0.26141 validloss=0.51638 accuracy_score=0.84061
#  88 10.04s trainloss=0.25866 validloss=0.51614 accuracy_score=0.84091
#  89 9.80s trainloss=0.25691 validloss=0.51331 accuracy_score=0.84157
#  90 10.20s trainloss=0.25478 validloss=0.51042 accuracy_score=0.84259
#  91 10.49s trainloss=0.25291 validloss=0.50833 accuracy_score=0.84359
#  92 10.51s trainloss=0.25067 validloss=0.50772 accuracy_score=0.84420
#  93 10.50s trainloss=0.24837 validloss=0.50718 accuracy_score=0.84480
#  94 10.58s trainloss=0.24610 validloss=0.50708 accuracy_score=0.84539
#  95 10.05s trainloss=0.24394 validloss=0.50709 accuracy_score=0.84632
#  96 10.59s trainloss=0.24164 validloss=0.50781 accuracy_score=0.84653
#  97 9.03s trainloss=0.23930 validloss=0.50882 accuracy_score=0.84674
#  98 7.60s trainloss=0.23696 validloss=0.50973 accuracy_score=0.84694
#  99 7.75s trainloss=0.23474 validloss=0.50935 accuracy_score=0.84747
# 100 7.54s trainloss=0.23243 validloss=0.50799 accuracy_score=0.84867

# %%
t.learning_curve()

# %%
t.validation_curve()

# %%
model = model.to('cpu')  # 如果模型在 GPU 上，转移到 CPU

# %%
model_weights = model.state_dict()

# 保存权重到文件
torch.save(model_weights, 'model_weights_3.pth')

# %%
print("Class to Index mapping:", train_ds.class_to_idx)
# Out:
# Class to Index mapping: {'left': 0, 'right': 1, 'straight': 2}
